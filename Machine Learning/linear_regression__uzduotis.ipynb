# %% [markdown]
# # Tiesinė regresija užduotis

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25460\1050519788.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# %matplotlib inline

# %%
fish = pd.read_csv('https://raw.githubusercontent.com/robotautas/kursas/master/Machine%20Learning/Fish.csv')

# %%
fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# ### Užduotis
# Turime lentelę su 7 žuvų rūšim, bei įvairiais jų išmatavimais. Vienas iš jų yra svoris - tai bus mūsų *target* stulpelis. **Sukurkite tiesinės regresijos modelį, kuris pagal kitus lentelės stulpelius spėlios žuvies svorį.** Išsiaiškinkite, ar yra trūkstamų reikšmių, atsispausdinkite keletą diagramų ir histogramų, patyrinėkite tendencijas ir koreliacijas. Kilus neaiškumams, remkitės paskaitos medžiaga. Sėkmės!

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
sns.set_style('darkgrid')

# %%
sns.countplot(x=fish['Species'], palette='Set2', hue=fish['Species'])
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.boxplot(x='Species', y='Weight', data=fish, palette='Set2',hue=fish['Species'])
# Out:
# <Axes: xlabel='Species', ylabel='Weight'>

# %%
sns.heatmap(fish.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(fish, hue='Species', diag_kind='histograma')

# %%
dummies =pd.get_dummies(fish['Species'])
data = pd.concat([fish, dummies], axis=1)
data.drop('Species', axis=1, inplace=True)

# %%
data.head(160)
# Out:
#      Weight  Length1  Length2  Length3   Height   Width  Bream  Parkki  Perch  \
# 0     242.0     23.2     25.4     30.0  11.5200  4.0200   True   False  False
# 1     290.0     24.0     26.3     31.2  12.4800  4.3056   True   False  False
# 2     340.0     23.9     26.5     31.1  12.3778  4.6961   True   False  False
# 3     363.0     26.3     29.0     33.5  12.7300  4.4555   True   False  False
# 4     430.0     26.5     29.0     34.0  12.4440  5.1340   True   False  False
# ..      ...      ...      ...      ...      ...     ...    ...     ...    ...
# 154    12.2     11.5     12.2     13.4   2.0904  1.3936  False   False  False
# 155    13.4     11.7     12.4     13.5   2.4300  1.2690  False   False  False
# 156    12.2     12.1     13.0     13.8   2.2770  1.2558  False   False  False
# 157    19.7     13.2     14.3     15.2   2.8728  2.0672  False   False  False
# 158    19.9     13.8     15.0     16.2   2.9322  1.8792  False   False  False
#
#       Pike  Roach  Smelt  Whitefish
# 0    False  False  False      False
# 1    False  False  False      False
# 2    False  False  False      False
# 3    False  False  False      False
# 4    False  False  False      False
# ..     ...    ...    ...        ...
# 154  False  False   True      False
# 155  False  False   True      False
# 156  False  False   True      False
# 157  False  False   True      False
# 158  False  False   True      False
#
# [159 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['Weight', 'Length1', 'Length2', 'Length3', 'Height', 'Width', 'Bream',
#        'Parkki', 'Perch', 'Pike', 'Roach', 'Smelt', 'Whitefish'],
#       dtype='object')

# %%
X = data[['Length1', 'Length2', 'Length3', 'Height', 'Width', 'Bream',
       'Parkki', 'Perch', 'Pike', 'Roach', 'Smelt', 'Whitefish']]
y = data['Weight']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = \
train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_test, y_test)
# Out:
# 0.9405192628555377

# %%
preds = reg.predict(X_test)

# %%
new_column = pd.Series(data=preds, name="Pred_Weight")

# %%
new_column.head()
# Out:
# 0     25.241369
# 1      0.595421
# 2    208.449859
# 3    331.665261
# 4    215.482994
# Name: pred_Weight, dtype: float64

# %%
y_test.head()
# Out:
# 78      78.0
# 155     13.4
# 128    200.0
# 55     270.0
# 94     150.0
# Name: Weight, dtype: float64

# %%
res = pd.concat([y_test.reset_index(), new_column],axis=1)[['Weight', 'Pred_Weight']]   #

# %%
res = pd.concat([y_test.reset_index(), new_column], axis=1)[['Weight', 'Pred_Weight']]

# %%
res
# Out:
#     Weight  Pred_Weight
# 0     78.0    25.241369
# 1     13.4     0.595421
# 2    200.0   208.449859
# 3    270.0   331.665261
# 4    150.0   215.482994
# 5   1000.0   753.929942
# 6      7.0   -72.458507
# 7    180.0   253.698723
# 8    188.0   259.678480
# 9   1250.0  1186.485729
# 10   650.0   600.206027
# 11  1000.0   847.635320
# 12   600.0   537.239650
# 13   150.0   152.193053
# 14   700.0   678.093881
# 15   920.0   817.925786
# 16  1000.0  1020.854225
# 17   218.0   281.460586
# 18   225.0   221.230474
# 19   700.0   580.928938
# 20    10.0   -26.598300
# 21   610.0   579.658685
# 22   500.0   506.143757
# 23   500.0   479.971143
# 24   955.0   814.231017
# 25  1100.0   965.625735
# 26   170.0   218.708642
# 27   270.0   355.983349
# 28     6.7  -102.621031
# 29     9.9   -28.099910
# 30   510.0   598.136370
# 31    70.0   -18.010507
# 32    51.5  -104.683495
# 33   567.0   728.061602
# 34   340.0   358.027459
# 35   120.0   163.308996
# 36   160.0   188.699604
# 37   120.0   109.828388
# 38   145.0   204.508008
# 39   820.0   780.041169
# 40   720.0   678.083828
# 41   500.0   728.191073
# 42     7.5   -76.786925
# 43   110.0   179.681138
# 44   140.0   192.874650
# 45    69.0     6.191816
# 46   110.0   135.603189
# 47   620.0   651.314578
# 48   130.0   135.643024
# 49    85.0    70.255777
# 50   685.0   720.492577
# 51   500.0   485.662042
# 52   514.0   538.647607
