# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14232\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## pirma dalis
# ---

# %%
labels = ('vardas', 'pavardė', 'amžius')
zmogus = ('Geras', 'Zmogelis', 33)
print(labels, zmogus)
# Out:
# ('vardas', 'pavardė', 'amžius') ('Geras', 'Zmogelis', 33)

# %%
pd.Series(data=zmogus)
# Out:
# 0       Geras
# 1    Zmogelis
# 2          33
# dtype: object

# %%
pd.Series(data=zmogus, index=labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_dict = {
    'vardas': 'Smagus',
    'pavarde': 'Giedriukas',
    'amzius': 36
}
zmogus_dict
# Out:
# {'vardas': 'Smagus', 'pavarde': 'Giedriukas', 'amzius': 36}

# %%
zmogus_pd = pd.Series(zmogus_dict)
zmogus_pd
# Out:
# vardas         Smagus
# pavarde    Giedriukas
# amzius             36
# dtype: object

# %%
pd.Series(zmogus, labels)
# Out:
# vardas        Geras
# pavardė    Zmogelis
# amžius           33
# dtype: object

# %%
zmogus_pd['amzius']
# Out:
# 36

# %%
miestai = pd.Series((500, 400, 300, 200), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
miestai
# Out:
# Vilnius     500
# Kaunas      400
# Klaipeda    300
# Siauliai    200
# dtype: int64

# %%
augimas = pd.Series((1.5, 1.3, 0.9, 0.7), ('Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai'))
augimas
# Out:
# Vilnius     1.5
# Kaunas      1.3
# Klaipeda    0.9
# Siauliai    0.7
# dtype: float64

# %%
miestai * augimas
# Out:
# Vilnius     750.0
# Kaunas      520.0
# Klaipeda    270.0
# Siauliai    140.0
# dtype: float64

# %%
betko7x7 = np.random.randint(10, 100, (7, 7))
betko7x7
# Out:
# array([[30, 75, 25, 15, 51, 10, 94],
#        [47, 95, 67, 70, 87, 54, 70],
#        [25, 50, 32, 15, 63, 44, 21],
#        [66, 17, 92, 25, 92, 24, 55],
#        [62, 48, 71, 74, 27, 14, 98],
#        [24, 15, 34, 83, 28, 63, 74],
#        [55, 79, 49, 36, 31, 79, 98]])

# %%
miestu_skaiciai = pd.DataFrame(
    betko7x7,
    [2000, 2004, 2008, 2012, 2016, 2020, 2024],
    ['Vilnius', 'Kaunas', 'Klaipeda', 'Siauliai', 'Panevezys', 'Alytus', 'Druskininkai']
)
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai
# 2000       30      75        25        15         51      10            94
# 2004       47      95        67        70         87      54            70
# 2008       25      50        32        15         63      44            21
# 2012       66      17        92        25         92      24            55
# 2016       62      48        71        74         27      14            98
# 2020       24      15        34        83         28      63            74
# 2024       55      79        49        36         31      79            98

# %%
miestu_skaiciai['Klaipeda']
# Out:
# 2000    25
# 2004    67
# 2008    32
# 2012    92
# 2016    71
# 2020    34
# 2024    49
# Name: Klaipeda, dtype: int32

# %%
print(type(miestu_skaiciai['Klaipeda']))
print(type(miestu_skaiciai))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
miestu_skaiciai[['Vilnius', 'Alytus', 'Druskininkai']]
# Out:
#       Vilnius  Alytus  Druskininkai
# 2000       30      10            94
# 2004       47      54            70
# 2008       25      44            21
# 2012       66      24            55
# 2016       62      14            98
# 2020       24      63            74
# 2024       55      79            98

# %%
miestu_skaiciai['Vilnius'][2000] = 99
miestu_skaiciai['Vilnius'][2000]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14232\2762690240.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   miestu_skaiciai['Vilnius'][2000] = 99
# 99

# %%
miestu_skaiciai.loc[2012]
# Out:
# Vilnius         66
# Kaunas          17
# Klaipeda        92
# Siauliai        25
# Panevezys       92
# Alytus          24
# Druskininkai    55
# Name: 2012, dtype: int32

# %%
kazluruda = pd.Series(np.random.randint(10, 99, 7), np.arange(2000, 2025, 4))
kazluruda
# Out:
# 2000    31
# 2004    38
# 2008    68
# 2012    45
# 2016    15
# 2020    90
# 2024    97
# dtype: int32

# %%
miestu_skaiciai['Kazlu Ruda'] = kazluruda
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Siauliai  Panevezys  Alytus  Druskininkai  \
# 2000       99      75        25        15         51      10            94
# 2004       47      95        67        70         87      54            70
# 2008       25      50        32        15         63      44            21
# 2012       66      17        92        25         92      24            55
# 2016       62      48        71        74         27      14            98
# 2020       24      15        34        83         28      63            74
# 2024       55      79        49        36         31      79            98
#
#       Kazlu Ruda
# 2000          31
# 2004          38
# 2008          68
# 2012          45
# 2016          15
# 2020          90
# 2024          97

# %%
miestu_skaiciai.drop('Siauliai', axis=1, inplace=True)

# %%
miestu_skaiciai
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      75        25         51      10            94          31
# 2004       47      95        67         87      54            70          38
# 2008       25      50        32         63      44            21          68
# 2012       66      17        92         92      24            55          45
# 2016       62      48        71         27      14            98          15
# 2020       24      15        34         28      63            74          90
# 2024       55      79        49         31      79            98          97

# %%
miestai_be_2008 = miestu_skaiciai.drop(2008)
miestai_be_2008
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      75        25         51      10            94          31
# 2004       47      95        67         87      54            70          38
# 2012       66      17        92         92      24            55          45
# 2016       62      48        71         27      14            98          15
# 2020       24      15        34         28      63            74          90
# 2024       55      79        49         31      79            98          97

# %%
miestu_skaiciai.loc[2008]
# Out:
# Vilnius         25
# Kaunas          50
# Klaipeda        32
# Panevezys       63
# Alytus          44
# Druskininkai    21
# Kazlu Ruda      68
# Name: 2008, dtype: int32

# %%
miestu_skaiciai.iloc[3]
# Out:
# Vilnius         66
# Kaunas          17
# Klaipeda        92
# Panevezys       92
# Alytus          24
# Druskininkai    55
# Kazlu Ruda      45
# Name: 2012, dtype: int32

# %%
miestu_skaiciai['Vilnius'][2020]
# Out:
# 24

# %%
miestu_skaiciai.loc[2020, 'Vilnius']
# Out:
# 24

# %%
miestu_skaiciai.loc[[2012, 2020, 2024], ['Kaunas', 'Alytus']]
# Out:
#       Kaunas  Alytus
# 2012      17      24
# 2020      15      63
# 2024      79      79

# %%
miestu_skaiciai[['Kaunas', 'Alytus']].loc[[2020, 2012, 2000]]
# Out:
#       Kaunas  Alytus
# 2020      15      63
# 2012      17      24
# 2000      75      10

# %%
miestu_skaiciai[miestu_skaiciai > 70]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000     99.0    75.0       NaN        NaN     NaN          94.0         NaN
# 2004      NaN    95.0       NaN       87.0     NaN           NaN         NaN
# 2008      NaN     NaN       NaN        NaN     NaN           NaN         NaN
# 2012      NaN     NaN      92.0       92.0     NaN           NaN         NaN
# 2016      NaN     NaN      71.0        NaN     NaN          98.0         NaN
# 2020      NaN     NaN       NaN        NaN     NaN          74.0        90.0
# 2024      NaN    79.0       NaN        NaN    79.0          98.0        97.0

# %%
print(miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 50])
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2004       47      95        67         87      54            70          38
# 2012       66      17        92         92      24            55          45
# 2016       62      48        71         27      14            98          15

# %%
miestu_skaiciai[miestu_skaiciai['Klaipeda'] > 80][['Vilnius', 'Klaipeda']]
# Out:
#       Vilnius  Klaipeda
# 2012       66        92

# %%
miestu_skaiciai[(miestu_skaiciai['Vilnius'] > 90) | (miestu_skaiciai['Klaipeda'] > 80)]
# Out:
#       Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda
# 2000       99      75        25         51      10            94          31
# 2012       66      17        92         92      24            55          45

# %%
miestu_skaiciai.reset_index()
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      75        25         51      10            94
# 1   2004       47      95        67         87      54            70
# 2   2008       25      50        32         63      44            21
# 3   2012       66      17        92         92      24            55
# 4   2016       62      48        71         27      14            98
# 5   2020       24      15        34         28      63            74
# 6   2024       55      79        49         31      79            98
#
#    Kazlu Ruda
# 0          31
# 1          38
# 2          68
# 3          45
# 4          15
# 5          90
# 6          97

# %%
be_indekso = miestu_skaiciai.reset_index()
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      75        25         51      10            94
# 1   2004       47      95        67         87      54            70
# 2   2008       25      50        32         63      44            21
# 3   2012       66      17        92         92      24            55
# 4   2016       62      48        71         27      14            98
# 5   2020       24      15        34         28      63            74
# 6   2024       55      79        49         31      79            98
#
#    Kazlu Ruda
# 0          31
# 1          38
# 2          68
# 3          45
# 4          15
# 5          90
# 6          97

# %%
be_indekso['Utena'] = np.random.randint(10, 71, 7)
be_indekso
# Out:
#    index  Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  \
# 0   2000       99      75        25         51      10            94
# 1   2004       47      95        67         87      54            70
# 2   2008       25      50        32         63      44            21
# 3   2012       66      17        92         92      24            55
# 4   2016       62      48        71         27      14            98
# 5   2020       24      15        34         28      63            74
# 6   2024       55      79        49         31      79            98
#
#    Kazlu Ruda  Utena
# 0          31     46
# 1          38     50
# 2          68     33
# 3          45     20
# 4          15     62
# 5          90     46
# 6          97     65

# %%
su_utena = be_indekso.set_index('index')
su_utena
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99      75        25         51      10            94          31
# 2004        47      95        67         87      54            70          38
# 2008        25      50        32         63      44            21          68
# 2012        66      17        92         92      24            55          45
# 2016        62      48        71         27      14            98          15
# 2020        24      15        34         28      63            74          90
# 2024        55      79        49         31      79            98          97
#
#        Utena
# index
# 2000      46
# 2004      50
# 2008      33
# 2012      20
# 2016      62
# 2020      46
# 2024      65

# %% [markdown]
# ## antra dalis
# ---

# %% [markdown]
# fiktyviai sugadianm duomenis

# %%
su_nuostoliu = su_utena[su_utena > 20]
su_nuostoliu
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    75.0        25         51     NaN            94        31.0
# 2004        47    95.0        67         87    54.0            70        38.0
# 2008        25    50.0        32         63    44.0            21        68.0
# 2012        66     NaN        92         92    24.0            55        45.0
# 2016        62    48.0        71         27     NaN            98         NaN
# 2020        24     NaN        34         28    63.0            74        90.0
# 2024        55    79.0        49         31    79.0            98        97.0
#
#        Utena
# index
# 2000    46.0
# 2004    50.0
# 2008    33.0
# 2012     NaN
# 2016    62.0
# 2020    46.0
# 2024    65.0

# %% [markdown]
# tikrinam duomenų kokybę, kur jų trūksta

# %%
su_nuostoliu.isnull()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000     False   False     False      False    True         False       False
# 2004     False   False     False      False   False         False       False
# 2008     False   False     False      False   False         False       False
# 2012     False    True     False      False   False         False       False
# 2016     False   False     False      False    True         False        True
# 2020     False    True     False      False   False         False       False
# 2024     False   False     False      False   False         False       False
#
#        Utena
# index
# 2000   False
# 2004   False
# 2008   False
# 2012    True
# 2016   False
# 2020   False
# 2024   False

# %%
su_nuostoliu.isnull().sum()
# Out:
# Vilnius         0
# Kaunas          2
# Klaipeda        0
# Panevezys       0
# Alytus          2
# Druskininkai    0
# Kazlu Ruda      1
# Utena           1
# dtype: int64

# %%
su_nuostoliu['Klaipeda'].isnull()
# Out:
# index
# 2000    False
# 2004    False
# 2008    False
# 2012    False
# 2016    False
# 2020    False
# 2024    False
# Name: Klaipeda, dtype: bool

# %%
su_nuostoliu['Klaipeda'].isnull().sum()
# Out:
# 0

# %% [markdown]
# išmetam eilutes, kur duomenų trūksta

# %%
su_nuostoliu.dropna()
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2004        47    95.0        67         87    54.0            70        38.0
# 2008        25    50.0        32         63    44.0            21        68.0
# 2024        55    79.0        49         31    79.0            98        97.0
#
#        Utena
# index
# 2004    50.0
# 2008    33.0
# 2024    65.0

# %% [markdown]
# išmetam stulpelius, kur duomenų trūksta

# %%
su_nuostoliu.dropna(axis=1)
# Out:
#        Vilnius  Klaipeda  Panevezys  Druskininkai
# index
# 2000        99        25         51            94
# 2004        47        67         87            70
# 2008        25        32         63            21
# 2012        66        92         92            55
# 2016        62        71         27            98
# 2020        24        34         28            74
# 2024        55        49         31            98

# %% [markdown]
# išmetam eilutes, kurių stulpelių duomenų kiekis neviršyja thresh

# %%
su_nuostoliu.dropna(thresh=7)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    75.0        25         51     NaN            94        31.0
# 2004        47    95.0        67         87    54.0            70        38.0
# 2008        25    50.0        32         63    44.0            21        68.0
# 2020        24     NaN        34         28    63.0            74        90.0
# 2024        55    79.0        49         31    79.0            98        97.0
#
#        Utena
# index
# 2000    46.0
# 2004    50.0
# 2008    33.0
# 2020    46.0
# 2024    65.0

# %% [markdown]
# išmetam stulpelius, kurių eilučių duomenų kiekis neviršyje thresh

# %%
su_nuostoliu.dropna(thresh=6, axis=1)
# Out:
#        Vilnius  Klaipeda  Panevezys  Druskininkai  Kazlu Ruda  Utena
# index
# 2000        99        25         51            94        31.0   46.0
# 2004        47        67         87            70        38.0   50.0
# 2008        25        32         63            21        68.0   33.0
# 2012        66        92         92            55        45.0    NaN
# 2016        62        71         27            98         NaN   62.0
# 2020        24        34         28            74        90.0   46.0
# 2024        55        49         31            98        97.0   65.0

# %% [markdown]
# užpildom nesamus duomenis 'kiauras' reikšme

# %%
su_nuostoliu.fillna('kiauras')
# Out:
#        Vilnius   Kaunas  Klaipeda  Panevezys   Alytus  Druskininkai  \
# index
# 2000        99     75.0        25         51  kiauras            94
# 2004        47     95.0        67         87     54.0            70
# 2008        25     50.0        32         63     44.0            21
# 2012        66  kiauras        92         92     24.0            55
# 2016        62     48.0        71         27  kiauras            98
# 2020        24  kiauras        34         28     63.0            74
# 2024        55     79.0        49         31     79.0            98
#
#       Kazlu Ruda    Utena
# index
# 2000        31.0     46.0
# 2004        38.0     50.0
# 2008        68.0     33.0
# 2012        45.0  kiauras
# 2016     kiauras     62.0
# 2020        90.0     46.0
# 2024        97.0     65.0

# %% [markdown]
# užpildome trūkstamus duomenis stulpelių vidurkiais

# %%
su_nuostoliu['Klaipeda'].fillna(value=su_nuostoliu['Klaipeda'].mean())
# Out:
# index
# 2000    25
# 2004    67
# 2008    32
# 2012    92
# 2016    71
# 2020    34
# 2024    49
# Name: Klaipeda, dtype: int32

# %%
padengti_nuostoliai = su_nuostoliu.fillna(value=su_nuostoliu.mean())
np.round(padengti_nuostoliai, 2)
# Out:
#        Vilnius  Kaunas  Klaipeda  Panevezys  Alytus  Druskininkai  Kazlu Ruda  \
# index
# 2000        99    75.0        25         51    52.8            94        31.0
# 2004        47    95.0        67         87    54.0            70        38.0
# 2008        25    50.0        32         63    44.0            21        68.0
# 2012        66    69.4        92         92    24.0            55        45.0
# 2016        62    48.0        71         27    52.8            98        61.5
# 2020        24    69.4        34         28    63.0            74        90.0
# 2024        55    79.0        49         31    79.0            98        97.0
#
#        Utena
# index
# 2000   46.00
# 2004   50.00
# 2008   33.00
# 2012   50.33
# 2016   62.00
# 2020   46.00
# 2024   65.00

# %% [markdown]
# ### grupavimas
#
# transponuojam lentelę, kad būtų patogiau dirbti su jos duomenimis

# %%
visi_miestai = su_utena.transpose()
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# Vilnius         99    47    25    66    62    24    55
# Kaunas          75    95    50    17    48    15    79
# Klaipeda        25    67    32    92    71    34    49
# Panevezys       51    87    63    92    27    28    31
# Alytus          10    54    44    24    14    63    79
# Druskininkai    94    70    21    55    98    74    98
# Kazlu Ruda      31    38    68    45    15    90    97
# Utena           46    50    33    20    62    46    65

# %% [markdown]
# pridedam regionus

# %%
regionai = pd.Series([
    'Miestas', 
    'Miestas', 
    'Mazoji Lietuva',
    'Aukstaitija', 
    'Dzukija', 
    'Dzukija', 
    'Mazoji Lietuva', 
    'Aukstaitija'
])
laikini = visi_miestai.reset_index()
laikini['regionai'] = regionai
visi_miestai = laikini.set_index('index')
visi_miestai
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    47    25    66    62    24    55         Miestas
# Kaunas          75    95    50    17    48    15    79         Miestas
# Klaipeda        25    67    32    92    71    34    49  Mazoji Lietuva
# Panevezys       51    87    63    92    27    28    31     Aukstaitija
# Alytus          10    54    44    24    14    63    79         Dzukija
# Druskininkai    94    70    21    55    98    74    98         Dzukija
# Kazlu Ruda      31    38    68    45    15    90    97  Mazoji Lietuva
# Utena           46    50    33    20    62    46    65     Aukstaitija

# %% [markdown]
# sugrupuojam miestus pagal regionus, išvedam vidurkių lentelę

# %%
regionais = visi_miestai.groupby('regionai')
regionais.mean(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija     48.5  68.5  48.0  56.0  44.5  37.0  48.0
# Dzukija         52.0  62.0  32.5  39.5  56.0  68.5  88.5
# Mazoji Lietuva  28.0  52.5  50.0  68.5  43.0  62.0  73.0
# Miestas         87.0  71.0  37.5  41.5  55.0  19.5  67.0

# %% [markdown]
# regionų suma

# %%
regionais.sum(numeric_only=True)
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       97   137    96   112    89    74    96
# Dzukija          104   124    65    79   112   137   177
# Mazoji Lietuva    56   105   100   137    86   124   146
# Miestas          174   142    75    83   110    39   134

# %% [markdown]
# regionų skaičius (realiai visų duomenų bus vienodas)

# %%
regionais.count()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija        2     2     2     2     2     2     2
# Dzukija            2     2     2     2     2     2     2
# Mazoji Lietuva     2     2     2     2     2     2     2
# Miestas            2     2     2     2     2     2     2

# %% [markdown]
# min/max

# %%
regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija       46    50    33    20    27    28    31
# Dzukija           10    54    21    24    14    63    79
# Mazoji Lietuva    25    38    32    45    15    34    49
# Miestas           75    47    25    17    48    15    55

# %%
regionais.max() - regionais.min()
# Out:
# index           2000  2004  2008  2012  2016  2020  2024
# regionai
# Aukstaitija        5    37    30    72    35    18    34
# Dzukija           84    16    23    31    84    11    19
# Mazoji Lietuva     6    29    36    47    56    56    48
# Miestas           24    48    25    49    14     9    24

# %% [markdown]
# statistinė analizė vieno stulpelio duomens

# %%
regionais[2024].describe()
# Out:
#                 count  mean        std   min    25%   50%    75%   max
# regionai
# Aukstaitija       2.0  48.0  24.041631  31.0  39.50  48.0  56.50  65.0
# Dzukija           2.0  88.5  13.435029  79.0  83.75  88.5  93.25  98.0
# Mazoji Lietuva    2.0  73.0  33.941125  49.0  61.00  73.0  85.00  97.0
# Miestas           2.0  67.0  16.970563  55.0  61.00  67.0  73.00  79.0

# %%
regionais[2024].describe().transpose()['Miestas']
# Out:
# count     2.000000
# mean     67.000000
# std      16.970563
# min      55.000000
# 25%      61.000000
# 50%      67.000000
# 75%      73.000000
# max      79.000000
# Name: Miestas, dtype: float64

# %% [markdown]
# ### DF jungimas

# %% [markdown]
# pasidalinam duomenis

# %%
iki_2010 = visi_miestai[['regionai', 2000, 2004, 2008]].copy()
po_2010 = visi_miestai[['regionai', 2012, 2016, 2020, 2024]].copy()

# %%
top4 = visi_miestai[:'Panevezys'].copy()
bottom4 = visi_miestai['Alytus':].copy()

# %%
pd.concat([top4, bottom4])
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius         99    47    25    66    62    24    55         Miestas
# Kaunas          75    95    50    17    48    15    79         Miestas
# Klaipeda        25    67    32    92    71    34    49  Mazoji Lietuva
# Panevezys       51    87    63    92    27    28    31     Aukstaitija
# Alytus          10    54    44    24    14    63    79         Dzukija
# Druskininkai    94    70    21    55    98    74    98         Dzukija
# Kazlu Ruda      31    38    68    45    15    90    97  Mazoji Lietuva
# Utena           46    50    33    20    62    46    65     Aukstaitija

# %%
pd.concat([top4, bottom4], axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024        regionai  2000  \
# index
# Vilnius       99.0  47.0  25.0  66.0  62.0  24.0  55.0         Miestas   NaN
# Kaunas        75.0  95.0  50.0  17.0  48.0  15.0  79.0         Miestas   NaN
# Klaipeda      25.0  67.0  32.0  92.0  71.0  34.0  49.0  Mazoji Lietuva   NaN
# Panevezys     51.0  87.0  63.0  92.0  27.0  28.0  31.0     Aukstaitija   NaN
# Alytus         NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  10.0
# Druskininkai   NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  94.0
# Kazlu Ruda     NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  31.0
# Utena          NaN   NaN   NaN   NaN   NaN   NaN   NaN             NaN  46.0
#
# index         2004  2008  2012  2016  2020  2024        regionai
# index
# Vilnius        NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Kaunas         NaN   NaN   NaN   NaN   NaN   NaN             NaN
# Klaipeda       NaN   NaN   NaN   NaN   NaN   NaN             NaN
# ...

# %%
right4 = bottom4.reset_index()
right4.drop(columns='regionai', inplace=True)
right4
# Out:
# index         index  2000  2004  2008  2012  2016  2020  2024
# 0            Alytus    10    54    44    24    14    63    79
# 1      Druskininkai    94    70    21    55    98    74    98
# 2        Kazlu Ruda    31    38    68    45    15    90    97
# 3             Utena    46    50    33    20    62    46    65

# %%
left4 = top4.reset_index().drop(columns='regionai')
left4
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024
# 0        Vilnius    99    47    25    66    62    24    55
# 1         Kaunas    75    95    50    17    48    15    79
# 2       Klaipeda    25    67    32    92    71    34    49
# 3      Panevezys    51    87    63    92    27    28    31

# %%
pd.concat([left4, right4], axis=1)
# Out:
# index      index  2000  2004  2008  2012  2016  2020  2024         index  \
# 0        Vilnius    99    47    25    66    62    24    55        Alytus
# 1         Kaunas    75    95    50    17    48    15    79  Druskininkai
# 2       Klaipeda    25    67    32    92    71    34    49    Kazlu Ruda
# 3      Panevezys    51    87    63    92    27    28    31         Utena
#
# index  2000  2004  2008  2012  2016  2020  2024
# 0        10    54    44    24    14    63    79
# 1        94    70    21    55    98    74    98
# 2        31    38    68    45    15    90    97
# 3        46    50    33    20    62    46    65

# %%
pd.concat([iki_2010, po_2010], axis=1).drop(columns='regionai', axis=1)
# Out:
# index         2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius         99    47    25    66    62    24    55
# Kaunas          75    95    50    17    48    15    79
# Klaipeda        25    67    32    92    71    34    49
# Panevezys       51    87    63    92    27    28    31
# Alytus          10    54    44    24    14    63    79
# Druskininkai    94    70    21    55    98    74    98
# Kazlu Ruda      31    38    68    45    15    90    97
# Utena           46    50    33    20    62    46    65

# %%
pd.merge(iki_2010, po_2010, on=['index', 'regionai'])
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    47    25    66    62    24    55
# Kaunas               Miestas    75    95    50    17    48    15    79
# Klaipeda      Mazoji Lietuva    25    67    32    92    71    34    49
# Panevezys        Aukstaitija    51    87    63    92    27    28    31
# Alytus               Dzukija    10    54    44    24    14    63    79
# Druskininkai         Dzukija    94    70    21    55    98    74    98
# Kazlu Ruda    Mazoji Lietuva    31    38    68    45    15    90    97
# Utena            Aukstaitija    46    50    33    20    62    46    65

# %%
iki_2010.join(po_2010, lsuffix='', rsuffix=':R').drop(columns='regionai:R')
# Out:
# index               regionai  2000  2004  2008  2012  2016  2020  2024
# index
# Vilnius              Miestas    99    47    25    66    62    24    55
# Kaunas               Miestas    75    95    50    17    48    15    79
# Klaipeda      Mazoji Lietuva    25    67    32    92    71    34    49
# Panevezys        Aukstaitija    51    87    63    92    27    28    31
# Alytus               Dzukija    10    54    44    24    14    63    79
# Druskininkai         Dzukija    94    70    21    55    98    74    98
# Kazlu Ruda    Mazoji Lietuva    31    38    68    45    15    90    97
# Utena            Aukstaitija    46    50    33    20    62    46    65

# %% [markdown]
# ## Duomenų skaitymas/rašymas
# ---

# %%
top = pd.read_csv('top50.csv', encoding='ISO-8859-1')
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
top['Genre'].unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
top['Genre'].nunique()
# Out:
# 21

# %%
top['Genre'].value_counts()
# Out:
# Genre
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# reggaeton           2
# reggaeton flow      2
# panamanian pop      2
# canadian pop        2
# electropop          2
# country rap         2
# dfw rap             2
# brostep             2
# trap music          1
# escape room         1
# pop house           1
# australian pop      1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: count, dtype: int64

# %%
top['Length.'].sum()
# Out:
# 10048

# %%
def minutes_seconds(length):
    return f"{length // 60}:{(length % 60):02d}"

# %%
top['Length.'].apply(minutes_seconds).head()
# Out:
# 0    3:11
# 1    5:02
# 2    3:06
# 3    3:18
# 4    2:55
# Name: Length., dtype: object

# %%
top['Length.Pretty'] = top['Length.'].apply(minutes_seconds)
top.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
top['Energy'].apply(lambda energy:energy // 10).head()
# Out:
# 0    5
# 1    8
# 2    8
# 3    6
# 4    6
# Name: Energy, dtype: int64

# %%
top.drop('Unnamed: 0', axis=1, inplace=True)

# %%
top.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.', 'Length.',
#        'Acousticness..', 'Speechiness.', 'Popularity', 'Length.Pretty'],
#       dtype='object')

# %%
top.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
top.shape
# Out:
# (50, 14)

# %%
top.sort_values('Beats.Per.Minute', ascending=False).head()
# Out:
#                        Track.Name    Artist.Name           Genre  \
# 2   boyfriend (with Social House)  Ariana Grande       dance pop
# 6                          Ransom      Lil Tecca      trap music
# 10                       Callaita      Bad Bunny       reggaeton
# 36                     Otro Trago           Sech  panamanian pop
# 46                      Te Robaré      Nicky Jam           latin
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 2                190      80            40              -4        16
# 6                180      64            75              -6         7
# 10               176      62            61              -5        24
# 36               176      70            75              -5        11
# 46               176      75            67              -4         8
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity Length.Pretty
# 2         70      186              12            46          85          3:06
# ...

# %%
top_speed = top.sort_values('Beats.Per.Minute', ascending=False)
top_speed.to_csv('top50_fastest.csv', index=True, index_label='Top.Index')

# %%
excel_writer = pd.ExcelWriter('top_speeed.xls', engine='xlsxwriter')
top_speed.to_excel(excel_writer, sheet_name='Fastest BPM')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 excel_writer = pd.ExcelWriter('top_speeed.xls', engine='xlsxwriter')
#       2 top_speed.to_excel(excel_writer, sheet_name='Fastest BPM')
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:197, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     184 def __init__(
#     185     self,
#     186     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#     195 ) -> None:
#     196     # Use the xlsxwriter module as the Excel writer.
# --> 197     from xlsxwriter import Workbook
#     199     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#     201     if mode == "a":
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %% [markdown]
# ### HTML

# %%
html_data = pd.read_html('https://lt.wikipedia.org/wiki/Vilniaus_miesto_savivaldyb%C4%97')

# %%
seniunijos = html_data[5]
seniunijos.head()
# Out:
#                 Seniūnija Plotas km²  Gyventojai  (2023 m.)  \
# 0    Antakalnio seniūnija   77,2 km²                  43027
# 1  Fabijoniškių seniūnija   5,87 km²                  37360
# 2     Grigiškių seniūnija    7,1 km²                  10685
# 3   Justiniškių seniūnija   2,98 km²                  26263
# 4  Karoliniškių seniūnija    4,0 km²                  24643
#
#   Gyventojų tankumas km²  (2023 m.)
# 0                       557 žm./km²
# 1                      6365 žm./km²
# 2                      1505 žm./km²
# 3                      8813 žm./km²
# 4                      6161 žm./km²

# %% [markdown]
# YAHOO.FINANCE
# ----------------------------

# %%
html_d = pd.read_html('https://finance.yahoo.com/chart/BTC-USD?showOptin=1#...-')

# %%
duom = html_d[10]
duom.head()
# Out:
#    Symbol  Last Price
# 0     NaN         NaN
# 1     NaN         NaN
# 2     NaN         NaN
# 3     NaN         NaN
# 4     NaN         NaN

# %%
from sqlalchemy import create_engine
db_engine = create_engine('sqlite:///db/seniunijos.db')

# %%
seniunijos.to_sql('seniunijos', con=db_engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 seniunijos.to_sql('seniunijos', con=db_engine, index=False)
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\pandas\core\generic.py:3081, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
# ...

# %%
school_engine = create_engine('sqlite:///db/school/school.db')
schedule = pd.read_sql('schedule', con=school_engine)
schedule.head()
# Out:
#    id  weekday start_time  subject_id  classroom_id  teacher_id
# 0  41        0   08:00:00           1             1           1
# 1  42        0   13:00:00           2             1           2
# 2  43        1   08:00:00           1             1           1
# 3  44        1   13:00:00           3             1           3
# 4  45        2   08:00:00           1             1           1

# %%
query = '''SELECT weekday, start_time, subject.name, codename, teacher.last_name
FROM schedule
JOIN subject ON schedule.subject_id=subject.id
JOIN classroom ON schedule.classroom_id=classroom.id
JOIN teacher ON schedule.teacher_id=teacher.id;
'''
nice_schedule = pd.read_sql_query(query, con=school_engine)
nice_schedule
# Out:
#     weekday start_time        name codename  last_name
# 0         0   08:00:00      Python   code01  Petraitis
# 1         0   13:00:00  JavaScript   code01     Onaite
# 2         1   08:00:00      Python   code01  Petraitis
# 3         1   13:00:00    HTML/CSS   code01    Marijus
# 4         2   08:00:00      Python   code01  Petraitis
# 5         2   13:00:00  JavaScript   code01     Onaite
# 6         3   08:00:00      Python   code01  Petraitis
# 7         3   13:00:00    HTML/CSS   code01    Marijus
# 8         0   08:00:00      Python   code02    Rasaite
# 9         0   13:00:00    HTML/CSS   code02    Marijus
# 10        1   08:00:00      Python   code02    Rasaite
# 11        1   13:00:00  JavaScript   code02     Onaite
# 12        2   08:00:00      Python   code02    Rasaite
# 13        2   13:00:00    HTML/CSS   code02    Marijus
# 14        3   08:00:00      Python   code02    Rasaite
# 15        3   13:00:00  JavaScript   code02     Onaite
# ...
