# %% [markdown]
# # Seaborn užduotys

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23500\1912426117.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# %matplotlib inline reikalingas, jei dirbame brauseryje

# %%
# %matplotlib inline

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
# 5          70    usa           ford galaxie 500
# 6          70    usa           chevrolet impala
# 7          70    usa          plymouth fury iii
# 8          70    usa           pontiac catalina
# 9          70    usa         amc ambassador dpl

# %%
mpg.shape
# Out:
# (398, 9)

# %% [markdown]
# **Reikšmės, kurios galbūt ne visai aiškios:**
# * mpg - miles per gallon
# * displacement - variklio tūris kubiniais coliais. Jei norite pasisunkinti, galite perkaičiuoti stulpelius europietiškais standartais :)

# %% [markdown]
# # 1 Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių turi kokią akseleraciją. *Šioje ir kitose užduotyse žaiskite su stiliais ir spalvomis, taip, kaip jums patinka.*

# %%
sns.displot(mpg['acceleration'])

# %% [markdown]
# # 2 Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių turi kokius variklio tūrius.

# %%
sns.displot(mpg['displacement'])

# %% [markdown]
# # 3 Atspausdinkite histogramą, kurioje matytųsi, kokie yra cilindrų skaičiaus variantai.

# %%
sns.displot(mpg['cylinders'])

# %%
sns.countplot(x='cylinders', data=mpg)
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %% [markdown]
# # 4 Atspausdinkite histogramą, kurioje matytųsi, kiek yra pagaminimo metų variantų

# %%
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
sns.countplot(x='model_year', data= mpg, palette='tab10')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17444\3502279335.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='model_year', data= mpg, palette='tab10')
# <Axes: xlabel='model_year', ylabel='count'>

# %% [markdown]
# # 5 Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių lentelėje kokia šalis pagamino.

# %%
sns.countplot(x='origin', data=mpg, palette='Set2')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17444\2165092724.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='origin', data=mpg, palette='Set2')
# <Axes: xlabel='origin', ylabel='count'>

# %% [markdown]
# # 6 Atspausdinkite histogramą, kurioje matytųsi, koks kurioje šalyje pagamintų automobilių variklio tūrio vidurkis.

# %%
sns.barplot(x='origin', y='displacement', data=mpg, errorbar=('ci', False))
# Out:
# <Axes: xlabel='origin', ylabel='displacement'>

# %% [markdown]
# # 6 Atspausdinkite sklaidos diagramą, kurios x ašis būtų 'displacement', y - 'acceleration', taip pat kiekvienas taškas atspindėtų šalį gamintoją ir cilindrų skaičių

# %%
sns.scatterplot(x='displacement', y='acceleration', data=mpg, hue='origin', size='cylinders', palette='Set2' )
# Out:
# <Axes: xlabel='displacement', ylabel='acceleration'>

# %% [markdown]
# # 7 Atspausdinkite visas įmanomas sklaidos diagramas lentelėje, kur pagal taško spalvą matytumėm šalį gamintoją. Kokias tendencijas galima aiškiai išskirti?

# %%
sns.pairplot(data=mpg)

# %%
sns.pairplot(data=mpg, hue='origin', palette='tab10')

# %% [markdown]
# # 8 Atspausdinkite stulpelinę diagramą, 'origin' x 'mpg'. Pabandykite interpretuoti rezultatą.

# %%
sns.barplot(x='origin', y='mpg', data=mpg)
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin', y='mpg', data=mpg, palette='tab10', hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# # 9 Sukurkite koreliacijų matricą. Jos pagrindu atspausdinkite mozaikinę diagramą.

# %%
korialiacija = mpg.corr(numeric_only=True)

# %%
korialiacija
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sns.heatmap(korialiacija, cmap='BrBG')
# Out:
# <Axes: >

# %%
sns.heatmap(korialiacija, annot=True, cmap='BrBG') #ANOTACIJA IVEDA DUOMENIS (CIA: KOREALECIJOS KOEFICIANTA)
# Out:
# <Axes: >

# %% [markdown]
# # 10 Atspausdinkite sklaidos diagramų rinkinį, kuriame kiekviena lentelė pagal šalį rodytų 'acceleration' ir 'mpg' sąntykį.

# %%
sns.scatterplot(x='accelaration', y='cylinders', data='origin')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 sns.scatterplot(x='accelaration', y='cylinders', data='origin')
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\seaborn\relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\seaborn\_core\data.py:57, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
# ---> 57     data = handle_data_source(data)
#      58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#
# File c:\Users\DELL\codeacadamy\course-python-basic\venv\Lib\site-packages\seaborn\_core\data.py:278, in handle_data_source(data)
#     276 elif data is not None and not isinstance(data, Mapping):
#     277     err = f"Data source must be a DataFrame or Mapping, not {type(data)!r}."
# --> 278     raise TypeError(err)
#     280 return data
#
# TypeError: Data source must be a DataFrame or Mapping, not <class 'str'>.

# %%
grafiku_rinkinys = sns.FacetGrid(data=mpg, col='origin')
grafiku_rinkinys.map(sns.scatterplot, 'acceleration', 'cylinders', palette='dark:salmon_r', data= mpg, hue='mpg')

# %%
# Sukurti FacetGrid objektą su duomenimis mpg ir sudaryti tinklelį pagal stulpelį 'origin'
grid = sns.FacetGrid(data=mpg, col='origin')

# Pridėti pasiskirstymo diagramas prie tinklelio su 'displacement' stulpeliu
grid.map(sns.histplot, 'displacement', 'cylinders') 
#Variklio turis - displacement

# %%
akseleracija = sns.FacetGrid(data=mpg, col='origin')
akseleracija.map(sns.histplot, 'acceleration')

# %%
sns.lmplot(x="acceleration", y="cylinders", data=mpg,
           order=2, ci=None, scatter_kws={"s": 80})


help("acceleration")
# Out:
# No Python documentation found for 'acceleration'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
